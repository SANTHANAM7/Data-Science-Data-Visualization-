# %% [markdown]
# <a href="https://colab.research.google.com/github/SANTHANAM7/Data-Science-Data-Visualization-/blob/main/untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import pandas as Pd
import pandas as pd
from google.colab import files
uploaded = files.upload()
gold_dataset=pd.read_csv("Gold vs USDINR.csv")
gold_dataset.head()
# Out:
#      <input type="file" id="files-92b24d7e-cf5e-4727-9fdf-51830a7aae2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92b24d7e-cf5e-4727-9fdf-51830a7aae2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gold_dataset.head()
# Out:
#          Date    USD_INR     Goldrate
# 0  2024-01-01  83.240601  â¹5,066.31
# 1  2024-01-08  83.076103  â¹4,966.31
# 2  2024-01-15  83.160599  â¹5,015.33
# 3  2024-01-22  83.146103  â¹4,950.84
# 4  2024-01-29  82.927597  â¹4,976.77

# %%
gold_dataset['Goldrate']=gold_dataset['Goldrate'].replace('','',regex=True).replace(',','',regex=True)
gold_dataset.head()
# Out:
#          Date    USD_INR    Goldrate
# 0  2024-01-01  83.240601  â¹5066.31
# 1  2024-01-08  83.076103  â¹4966.31
# 2  2024-01-15  83.160599  â¹5015.33
# 3  2024-01-22  83.146103  â¹4950.84
# 4  2024-01-29  82.927597  â¹4976.77

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(gold_dataset)
plt.show()

# %%
sns.boxplot(gold_dataset)
plt.show()

# %%
gold_dataset['Goldrate'] = pd.to_numeric(gold_dataset['Goldrate'])
sns.regplot(x='USD_INR',y='Goldrate',data=gold_dataset)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "â¹5066.31"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-6ef55afac6c9> in <cell line: 0>()
# ----> 1 gold_dataset['Goldrate'] = pd.to_numeric(gold_dataset['Goldrate'])
#       2 sns.regplot(x='USD_INR',y='Goldrate',data=gold_dataset)
#       3 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     230         coerce_numeric = errors not in ("ignore", "raise")
#     231         try:
# --> 232             values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233                 values,
# ...

# %%
x=gold_dataset['USD_INR']
y=gold_dataset['Goldrate']

x
# Out:
# 0     83.240601
# 1     83.076103
# 2     83.160599
# 3     83.146103
# 4     82.927597
# 5     82.985298
# 6     83.009598
# 7     82.872299
# 8     82.910400
# 9     82.752296
# 10    82.965599
# 11    83.226601
# 12    83.392998
# 13    83.477798
# 14    83.349297
# 15    83.544998
# 16    83.301804
# 17    83.406303
# 18    83.459396
# 19    83.470100
# 20    83.286400
# 21    83.320900
# 22    83.473099
# 23    83.522102
# 24    83.601601
# 25    83.450897
# 26    83.493401
# 27    83.518501
# 28    83.674301
# 29    83.744400
# 30    83.743896
# 31    83.988998
# 32    83.948303
# 33    83.940598
# 34    83.895103
# 35    83.983597
# 36    83.934799
# 37    83.614700
# 38    83.617104
# 39    84.009399
# 40    83.945999
# 41    84.053802
# 42    84.081802
# 43    84.091499
# 44    84.306396
# 45    84.473801
# 46    84.488297
# 47    84.556999
# 48    84.666000
# 49    84.802002
# 50    84.945000
# 51    85.386002
# 52    85.786598
# Name: USD_INR, dtype: float64
